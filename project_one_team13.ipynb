# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st


# Read the data files
jeopardy_teen_df= pd.read_csv('kids_teen.csv', sep='\t')
jeopardy_teen_df.head()
# Out:
#    round  value daily_double     category comments  \
# 0      1    100           no        BIRDS        -
# 1      1    200           no        BIRDS        -
# 2      1    300           no        BIRDS        -
# 3      1    100           no  THE LIBRARY        -
# 4      1    200           no  THE LIBRARY        -
#
#                                               answer  \
# 0  The bat parrot probably got its name from slee...
# 1  Too "lei"zy to migrate, the geese in this trop...
# 2  A bird waterproofs its feathers with oil from ...
# 3  Defacing books or shouting or throwing spitbal...
# 4  On most reference books in your local library,...
#
#                                      question    air_date  \
# 0                                 upside-down  1987-02-16
# 1                                      Hawaii  1987-02-16
# 2                                    its tail  1987-02-16
# 3  three activities prohibited in the library  1987-02-16
# 4                                           R  1987-02-16
#
#                                        notes
# 0  1987 Teen Tournament quarterfinal game 1.
# 1  1987 Teen Tournament quarterfinal game 1.
# 2  1987 Teen Tournament quarterfinal game 1.
# 3  1987 Teen Tournament quarterfinal game 1.
# 4  1987 Teen Tournament quarterfinal game 1.

# %%
# Read the data files
jeopardy_adult_df= pd.read_csv('master_season1-35.csv', sep='\t')
jeopardy_adult_df.head(30)
# Out:
#     round  value daily_double         category comments  \
# 0       1    100           no   LAKES & RIVERS        -
# 1       1    200           no   LAKES & RIVERS        -
# 2       1    400           no   LAKES & RIVERS        -
# 3       1    500           no   LAKES & RIVERS        -
# 4       1    100           no       INVENTIONS        -
# 5       1    200           no       INVENTIONS        -
# 6       1    300           no       INVENTIONS        -
# 7       1    400           no       INVENTIONS        -
# 8       1    100           no          ANIMALS        -
# 9       1    200           no          ANIMALS        -
# 10      1    300           no          ANIMALS        -
# 11      1    400           no          ANIMALS        -
# 12      1    500           no          ANIMALS        -
# 13      1    100           no  FOREIGN CUISINE        -
# 14      1    200           no  FOREIGN CUISINE        -
# 15      1    300           no  FOREIGN CUISINE        -
# 16      1    400           no  FOREIGN CUISINE        -
# 17      1    100           no   ACTORS & ROLES        -
# 18      1    200           no   ACTORS & ROLES        -
# 19      1    300           no   ACTORS & ROLES        -
# 20      1    400           no   ACTORS & ROLES        -
# 21      1    500           no   ACTORS & ROLES        -
# 22      2    200           no        THE BIBLE        -
# 23      2    400           no        THE BIBLE        -
# 24      2    600           no        THE BIBLE        -
# 25      2    800           no        THE BIBLE        -
# 26      2   1000           no        THE BIBLE        -
# 27      2    200           no        \'50'S TV        -
# 28      2    400           no        \'50'S TV        -
# 29      2    600           no        \'50'S TV        -
#
#                                                answer  \
# 0             River mentioned most often in the Bible
# 1                              Scottish word for lake
# 2   American river only 33 miles shorter than the ...
# 3   World's largest lake, nearly 5 times as big as...
# 4                        Marconi's wonderful wireless
# 5   In 1869 an American minister created this "ori...
# 6   A 1920's hunting trip to Canada inspired Birds...
# 7   This fastener gets its name from a brand of ga...
# 8   These rodents first got to America by stowing ...
# 9   There are about 40,000 muscles & tendons in th...
# 10  When husbands "pop" for an ermine coat, they'r...
# 11  Close relative of the pig, though its name mea...
# 12  If this species of hybrid's parents were rever...
# 13                            The "coq" in coq au vin
# 14  A British variety is called "bangers", a Mexic...
# 15                    Jewish crepe filled with cheese
# 16  French for a toothsome cut of beef served to a...
# 17  Video in which Michael Jackson plays a werewol...
# 18  2 "Saturday Night" alumni who tried "Trading P...
# 19  He may "Never Say Never Again" when asked to b...
# 20  The blonde preferred in the film "Gentlemen Pr...
# 21  Sam Shepard played this barrier breaker in "Th...
# 22  When "Joshua Fit The Battle Of Jericho", these...
# 23                  His price was 30 pieces of silver
# 24  According to the Bible, it wasn't necessarily ...
# 25  Though its name means "city of peace", it's se...
# 26  According to 1st Timothy, it is the "root of a...
# 27  Occupation of Richard Diamond, Peter Gunn & Mi...
# 28                         She was "Our Miss Brooks\"
# 29  Amount Michael Anthony gave out each week on b...
#
#                                              question    air_date notes
# 0                                          the Jordan  1984-09-10     -
# 1                                                loch  1984-09-10     -
# 2                                        the Missouri  1984-09-10     -
# 3                                     the Caspian Sea  1984-09-10     -
# 4                                           the radio  1984-09-10     -
# 5                                        the rickshaw  1984-09-10     -
# 6                                            freezing  1984-09-10     -
# 7                                            a zipper  1984-09-10     -
# 8                                                rats  1984-09-10     -
# 9                                           the trunk  1984-09-10     -
# 10                                           a weasel  1984-09-10     -
# 11                                   the hippopotamus  1984-09-10     -
# 12                                               mule  1984-09-10     -
# 13                                            chicken  1984-09-10     -
# 14                                           sausages  1984-09-10     -
# 15                                           a blintz  1984-09-10     -
# 16                                      Châteaubriand  1984-09-10     -
# 17                                       \"Thriller\"  1984-09-10     -
# 18                         Dan Aykroyd & Eddie Murphy  1984-09-10     -
# 19                                       Sean Connery  1984-09-10     -
# 20                                     Marilyn Monroe  1984-09-10     -
# 21                               Colonel Chuck Yeager  1984-09-10     -
# 22                                          the walls  1984-09-10     -
# 23                                              Judas  1984-09-10     -
# 24  the forbidden fruit (or the fruit of the Tree ...  1984-09-10     -
# 25                                          Jerusalem  1984-09-10     -
# 26                                  the love of money  1984-09-10     -
# 27               private eyes (or private detectives)  1984-09-10     -
# 28                                          Eve Arden  1984-09-10     -
# 29                                         $1 million  1984-09-10     -
